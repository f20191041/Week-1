# %%
import numpy as np
from skimage import io
from PIL import Image
photo=io.imread('image1.jpg')
io.imshow(photo)

# %%
arr1=np.array(photo)
arr1
# Out:
# array([[[136, 122, 148],
#         [136, 121, 150],
#         [156, 136, 171],
#         ...,
#         [190, 195, 173],
#         [182, 187, 164],
#         [195, 201, 175]],
#
#        [[137, 123, 149],
#         [137, 122, 151],
#         [150, 131, 163],
#         ...,
#         [192, 196, 179],
#         [187, 192, 172],
#         [193, 198, 176]],
#
#        [[136, 121, 150],
#         [138, 123, 152],
#         [143, 124, 156],
#         ...,
#         [208, 210, 197],
#         [209, 211, 197],
#         [210, 213, 196]],
#
#        ...,
#
#        [[ 83,  45,  84],
#         [ 86,  43,  86],
#         [ 88,  41,  87],
#         ...,
#         [219, 219, 229],
#         [220, 220, 230],
#         [220, 220, 230]],
#
#        [[ 89,  51, 100],
#         [ 82,  42,  92],
#         [ 76,  32,  85],
#         ...,
#         [219, 219, 229],
#         [220, 220, 230],
#         [220, 220, 230]],
#
#        [[ 76,  37,  92],
#         [ 76,  35,  91],
#         [ 77,  32,  89],
# ...

# %%
photo[: ,: ,: ]=255-photo[: ,: ,: ]
io.imshow(photo)

# %%
inv_arr=np.array(photo)
inv_arr
# Out:
# array([[[119, 133, 107],
#         [119, 134, 105],
#         [ 99, 119,  84],
#         ...,
#         [ 65,  60,  82],
#         [ 73,  68,  91],
#         [ 60,  54,  80]],
#
#        [[118, 132, 106],
#         [118, 133, 104],
#         [105, 124,  92],
#         ...,
#         [ 63,  59,  76],
#         [ 68,  63,  83],
#         [ 62,  57,  79]],
#
#        [[119, 134, 105],
#         [117, 132, 103],
#         [112, 131,  99],
#         ...,
#         [ 47,  45,  58],
#         [ 46,  44,  58],
#         [ 45,  42,  59]],
#
#        ...,
#
#        [[172, 210, 171],
#         [169, 212, 169],
#         [167, 214, 168],
#         ...,
#         [ 36,  36,  26],
#         [ 35,  35,  25],
#         [ 35,  35,  25]],
#
#        [[166, 204, 155],
#         [173, 213, 163],
#         [179, 223, 170],
#         ...,
#         [ 36,  36,  26],
#         [ 35,  35,  25],
#         [ 35,  35,  25]],
#
#        [[179, 218, 163],
#         [179, 220, 164],
#         [178, 223, 166],
# ...

# %%
inv_img=Image.fromarray(inv_arr)
inv_img.save('final.jpg')
